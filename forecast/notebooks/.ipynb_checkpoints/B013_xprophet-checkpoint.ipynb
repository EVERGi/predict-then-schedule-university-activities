# %%
import os, inspect
import sys
os.chdir(os.path.dirname(os.getcwd()))

# %%
import fnmatch

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
pd.options.mode.chained_assignment = None  # default='warn'
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import seaborn as sns
import matplotlib.pyplot as plt
import itertools


from prophet import Prophet
from prophet.diagnostics import cross_validation
from prophet.diagnostics import performance_metrics
from prophet.plot import plot_cross_validation_metric
import lightgbm as lgb
import optuna
from optuna.integration import LightGBMPruningCallback


from sklearn import metrics
from sklearn.metrics import mean_absolute_error
import pickle
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import VarianceThreshold
from scipy import stats

# %%
import_dir = './data/lgbm_inputs_phase2/'
# THIS IS THE LIST OF TIMESERIES WHERE NANS ARE FILLED WITH 0 FOR TRAINING
filelist = os.listdir(import_dir)
if ('.ipynb_checkpoints' in filelist):
    filelist.remove('.ipynb_checkpoints')
#buildings = fnmatch.filter(list(filelist),'Building*')
#buildings.remove('Building4.csv')
buildings = ['Building0.csv', 'Building1.csv', 'Building3.csv']
print(list(buildings))
plots_dir = './plots/'
log_dir = './logs/'
model_dir = './models/'
namerun = 'november_xp'
prophets_dir = './data/prophets/'
feature_plots_dir = './plots/importances/'
drop_features = ['y', 'value']
predictions = {}
results_df = pd.DataFrame()
prophets = {}
transform = 'log'
# Out:
# ['Building0.csv', 'Building1.csv', 'Building3.csv']

# %%
for i,filename in enumerate(buildings):
    path = os.path.join(import_dir, filename)
    input_ds = pd.read_csv(path, index_col='datetime', parse_dates=[0])
    input_ds = input_ds.rename({'value':'y'},axis=1)
    input_ds['ds'] = input_ds.index
    input_ds.index = input_ds.index.sort_values()
    # THE DATA AFTER WHICH THE TEST SERIES STARTS
    split_date = '01-Nov-2020'
    input_ds['value'] = input_ds['y']
    input_ds['y'] = np.log1p(input_ds['y'])
    # Separate dataframe for application in Prophet
    input_ds_prop = input_ds.dropna().copy()

    input_ds_train = input_ds_prop.loc[input_ds_prop.index < split_date].copy()
    input_ds_train = input_ds_train[(input_ds_train.value - input_ds_train.value.mean())/input_ds_train.value.std(ddof=0) < 3]
    param_grid = {  
        'changepoint_prior_scale': 0.05,
        'seasonality_prior_scale': 0.1,
        'changepoint_range': 0.9,
        'seasonality_mode': 'additive',
        'yearly_seasonality': True,
    }
    
    prop = Prophet(**param_grid)
    prop.add_country_holidays(country_name='Australia')
    #prop.add_regressor('max_temp_moorabbin')
    prop.fit(input_ds_train)

    future = prop.make_future_dataframe(periods=2976, freq='15T')
    #future = future.join(input_ds['max_temp_moorabbin'], how='outer', on='ds')

    forecast = prop.predict(future)
    fig1 = prop.plot(forecast)
    fig2 = prop.plot_components(forecast)
    prophets[filename] = forecast
    df_name = filename + '_' + transform
    forecast.to_csv(os.path.join(prophets_dir, df_name), index=False)
# Out:
# Initial log joint probability = -341.437
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99        243304     0.0108949       30422.4           1           1      126
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199        243564    0.00107659       2616.58           1           1      239
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299        243847   0.000840194       4024.03      0.2642      0.2642      349
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399        243914     0.0150032       4494.57       1.052      0.1052      463
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499        243965      0.003255       1428.74           1           1      577
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599        243982   0.000341356       1442.84           1           1      690
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699        244001   7.98613e-05       541.991           1           1      804
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799        244018   0.000674962       1234.66           1           1      916
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899        244033   0.000821247         896.9           1           1     1030
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999        244043   4.97221e-05        897.37      0.4245      0.4245     1143
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099        244059    0.00446074       3167.82           1           1     1254
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1199        244072     0.0160005       4504.29           1           1     1367
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1299        244078   0.000773471        1794.2           1           1     1484
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399        244079   0.000157406       485.892      0.5859      0.5859     1596
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1499        244083   5.54196e-05       504.896      0.3554      0.3554     1709
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1533        244083   0.000286209       128.393           1           1     1748
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -778.157
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       83626.7   0.000135969        164.03       0.301       0.301      120
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       83629.4    0.00335684       333.619       4.604      0.4604      234
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       83630.9   4.04012e-05       172.809    2.85e-07       0.001      393  LS failed, Hessian reset
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      343       83630.9   5.68441e-06       68.3507      0.3049           1      451
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -712.863
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99        451219   0.000235801       9225.31           1           1      121
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199        451411    0.00017915        4179.4           1           1      230
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299        451542     0.0008826       3217.03           1           1      342
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399        451598    0.00280525       7337.93           1           1      458
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499        451634    0.00119116       16850.8           1           1      570
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599        451671    0.00114889       6574.75           1           1      680
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699        451693   0.000406345       6444.81      0.2819      0.2819      792
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799        451746    0.00808028       6270.91      0.2812           1      910
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899        451768    0.00186437       2760.09           1           1     1025
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999        451784   0.000167837       973.763           1           1     1130
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099        451798    1.6663e-05       943.911           1           1     1239
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1199        451802   0.000599894       2142.41       1.329      0.1329     1351
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1299        451816   0.000623988       4613.71       0.347           1     1467
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399        451868    0.00342753       4574.32       4.223      0.4223     1575
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1499        451887    0.00628329       8413.11           1           1     1688
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1599        451903   0.000111991       2087.07      0.4786      0.4786     1802
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1699        451916    0.00175973       2461.62           1           1     1916
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1799        451927    0.00684786        1901.4           1           1     2032
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1899        451936   0.000172811       979.511      0.4535      0.4535     2146
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1999        451939   0.000617332       1772.64           1           1     2259
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2099        451944   4.05912e-05       822.134      0.7318      0.7318     2369
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2163        451945   0.000115047       348.298      0.3262      0.8622     2439
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance

# %%
input_ds.columns
# Out:
# Index(['y', 'max_temp_moorabbin', 'max_temp_olympic', 'min_temp_moorabbin',
#        'min_temp_olympic', 'rainfall_moorabbin', 'rainfall_oakleigh',
#        'rainfall_olympic', 'solar_moorabbin', 'solar_oakleigh',
#        'solar_olympic', 'temperature (degC)', 'dewpoint_temperature (degC)',
#        'wind_speed (m/s)', 'mean_sea_level_pressure (Pa)',
#        'relative_humidity ((0-1))', 'surface_solar_radiation (W/m^2)',
#        'surface_thermal_radiation (W/m^2)', 'total_cloud_cover (0-1)', 'RH',
#        'heat', 'windchill', 'feellike', 'occupancy', 'cos-month', 'sin-month',
#        'cos-dayofyear', 'sin-dayofyear', 'weekday', 'cos-hour', 'sin-hour',
#        'working', 'value', 'trend', 'trend_lower', 'trend_upper', 'daily',
#        'holidays', 'holidays_lower', 'holidays_upper', 'weekly', 'yearly',
#        'yearly_lower', 'yearly_upper'],
#       dtype='object')

# %%
plt.style.use('fivethirtyeight')

def plot_predictions(input_ds_all, name):
    # Plot the forecast with the actuals
    f, ax = plt.subplots(1)
    f.set_figheight(5)
    f.set_figwidth(15)
    _ = input_ds_all[['value','Prediction']].plot(ax=ax,
                                                  style=['-','-'])
    ax.set_xbound(lower='2020-09', upper='2020-10')
    plot = plt.suptitle(name, y=1.01)
    plot = plt.title('September 2020 Forecast vs Actuals')
    plt.show()
    
def plotImp(model, X , num = 20, fig_size = (40, 20)):
    feature_imp = pd.DataFrame({'Value':model.feature_importances_,'Feature':X.columns})
    plt.figure(figsize=fig_size)
    #sns.set(font_scale = 5)
    sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value", 
                                                        ascending=False)[0:num])
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()
    #plt.savefig('lgbm_importances-01.png')
    plt.show()
    
def weekly_persistence(input_ds_train):
    predictions = pd.Series(dtype='float64')
    #input_ds_train.value[-672:].plot()
    input_ds_train = input_ds_train.resample('15T').mean()
    input_ds_train = input_ds_train.fillna(value=0)
    last_week = input_ds_train.value[-672:]
    for i in range(len(X_test)//672 + 1):
    # get the data for the prior week 
        last_week.index = last_week.index.shift(freq='7D')
        #last_week.plot()
        predictions = predictions.append(last_week)
        #print(predictions)
    #print(predictions)
    predictions = predictions['2020-10']
    return predictions

def objective(trial, input_X, input_y):
    param = {
        'metric': 'l1', 
        'random_state': 48,
        "n_estimators": trial.suggest_categorical("n_estimators", [10000]),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "num_leaves": trial.suggest_int("num_leaves", 20, 3000, step=20),
        "max_depth": trial.suggest_categorical("max_depth", [-1, 5, 10, 15, 20, 25]), 
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 10, 100, step=10),
        "lambda_l1": trial.suggest_int("lambda_l1", 0, 100, step=5),
        "lambda_l2": trial.suggest_int("lambda_l2", 0, 100, step=5),
#         'colsample_bytree': trial.suggest_categorical('colsample_bytree', [0.3,0.4,0.5,0.6,0.7,0.8,0.9, 1.0]),
#         'subsample': trial.suggest_categorical('subsample', [0.4,0.5,0.6,0.7,0.8,1.0]),
#         'min_child_samples': trial.suggest_int('min_child_samples', 1, 300),
#         'cat_smooth' : trial.suggest_int('min_data_per_groups', 1, 100)
    }

    train_date = '01-Sep-2020'
    split_date = '01-Oct-2020'
    correlated_features = set()
    correlation_matrix = input_X.corr()
    for i in range(len(correlation_matrix.columns)):
        for j in range(i):
            if abs(correlation_matrix.iloc[i, j]) > trial.suggest_categorical("correlation_value", [0.6, 0.7, 0.8, 0.9, 1]):
                colname = correlation_matrix.columns[i]
                correlated_features.add(colname)
    
    # Make temporary division
    X_train, y_train = input_X.loc[input_X.index < train_date].copy(), input_y.loc[input_y.index < train_date].copy()
    X_eval, y_eval = input_X.loc[(input_X.index >= train_date) & (input_X.index < split_date)].copy(), input_y.loc[(input_y.index >= train_date) & (input_y.index < split_date)].copy()
                
    X_train.drop(labels=correlated_features, axis=1, inplace=True)
    X_eval.drop(labels=correlated_features, axis=1, inplace=True)
    
#     ds_train = lgb.Dataset(X_train, y_train, categorical_feature=['working', 'weekday']) 
#     ds_validate = lgb.Dataset(X_eval, y_eval, categorical_feature=['working', 'weekday']) 
    
    model= lgb.train(
        X_train, 
        y_train,                     
        eval_set=[(X_eval, y_eval)],
        early_stopping_rounds=50,
        params=param,
        callbacks=[
            LightGBMPruningCallback(trial, "l1")
        ],  # Add a pruning callback
    )
    
    preds = model.predict(X_eval)
    mae = mean_absolute_error(y_eval, preds)
    trial.set_user_attr(key="best_booster", value=model)
    return mae

def callback(study, trial):
    if study.best_trial.number == trial.number:
        study.set_user_attr(key="best_booster", value=trial.user_attrs["best_booster"])

# %%
for i,filename in enumerate(buildings):
    path = os.path.join(import_dir, filename)
    input_ds = pd.read_csv(path, index_col='datetime', parse_dates=[0])
    input_ds = input_ds.rename({'value':'y'},axis=1)
    input_ds['value'] = input_ds['y']
    input_ds['y'] = np.log1p(input_ds['y'])
    input_ds.index = input_ds.index.sort_values()
    #forecast = prophets[filename]
    df_name = filename + '_' + transform
    forecast = pd.read_csv(os.path.join(prophets_dir, df_name), index_col='ds', parse_dates=[0])

    input_ds = input_ds.join(forecast.drop(['yhat', 'additive_terms', 'additive_terms_lower', 'additive_terms_upper', 'daily_lower', 'daily_upper', 'weekly_lower', 'weekly_upper', 'yhat_upper', 'yhat_lower', 'ds', 'multiplicative_terms', 'multiplicative_terms_lower', 'multiplicative_terms_upper', 'Anzac Day', 'Anzac Day_lower', 'Anzac Day_upper', 'Australia Day',
       'Australia Day_lower', 'Australia Day_upper',
       'Australia Day (Observed)', 'Australia Day (Observed)_lower',
       'Australia Day (Observed)_upper', 'Boxing Day', 'Boxing Day_lower',
       'Boxing Day_upper', 'Boxing Day (Observed)',
       'Boxing Day (Observed)_lower', 'Boxing Day (Observed)_upper',
       'Christmas Day', 'Christmas Day_lower', 'Christmas Day_upper',
       'Christmas Day (Observed)', 'Christmas Day (Observed)_lower',
       'Christmas Day (Observed)_upper', 'Easter Monday',
       'Easter Monday_lower', 'Easter Monday_upper', 'Good Friday',
       'Good Friday_lower', 'Good Friday_upper', 'New Year\'s Day',
       'New Year\'s Day_lower', 'New Year\'s Day_upper',
       'New Year\'s Day (Observed)', 'New Year\'s Day (Observed)_lower',
       'New Year\'s Day (Observed)_upper'], axis=1, errors='ignore'))

    # THE DATA AFTER WHICH THE TEST SERIES STARTS
    train_date = '01-Oct-2020'
    split_date = '01-Nov-2020'

    # Divide features and labels 
    input_X, input_y = input_ds.loc[input_ds.index < split_date].dropna().iloc[:,1:], input_ds.loc[input_ds.index < split_date].dropna().iloc[:,0]

    # Create study that minimizes
    study = optuna.create_study(direction="minimize")

    # Pass additional arguments inside another function
    func = lambda trial: objective(trial, input_X, input_y)

    # Start optimizing with 100 trials
    study.optimize(func, n_trials=200, callbacks=[callback])

    correlated_features = set()
    correlation_matrix = input_X.corr()
    for i in range(len(correlation_matrix.columns)):
        for j in range(i):
            if abs(correlation_matrix.iloc[i, j]) > study.best_trial.params['correlation_value']:
                colname = correlation_matrix.columns[i]
                correlated_features.add(colname)

    X_train, y_train = input_X.loc[input_X.index < train_date].copy(), input_y.loc[input_y.index < train_date].copy()
    X_test, y_test = input_X.loc[input_X.index >= split_date].copy(), input_y.loc[input_y.index >= split_date].copy()

    n = len(X_train)

    X_test = X_test.fillna(value=0)
    X_test.drop(labels=correlated_features, axis=1, inplace=True)


    print(f"Optimized MAE: {study.best_value:.5f}")
    print(filename)
    print('Number of finished trials:', len(study.trials))
    print('Best trial:', study.best_trial.params)
    f = open(log_dir+namerun+"{}_log.txt".format(os.path.splitext(filename)[0]), "w+")
    f.write(filename)
    f.write('\n')
    f.write('MAE error is:{}\n'.format(study.best_value))
    f.write('Number of finished trials:{}\n'.format(len(study.trials)))
    f.write('Best trial:{}\n'.format(study.best_trial.params))
    f.close()
    best_model=study.user_attrs["best_booster"]
    # save the model
    pickle.dump(best_model, open(model_dir+namerun+"_best_{}.pkl".format(os.path.splitext(filename)[0]), "wb"))
    # load the model
    lgbmodel = pickle.load(open(model_dir+namerun+"_best_{}.pkl".format(os.path.splitext(filename)[0]), "rb"))
    # predict the test dataset
    add_forecast = pd.DataFrame(lgbmodel.predict(X_test), index=input_ds_test.index, columns=['additive'])

    forecast = pd.DataFrame(add_forecast['additive'], index=input_ds_test.index, columns=['additive'])
    forecast = np.expm1(forecast)
    
    #Plotting feature importance
    f_imp, ax_imp = plt.subplots(1, figsize=(30,15))
    plt.gcf().subplots_adjust(left=0.5)
    lgb.plot_importance(lgbmodel, height=0.3, ax=ax_imp) 
    plt.savefig(feature_plots_dir+namerun+'_{}.png'.format(os.path.splitext(filename)[0]))
    
    #plotImp(lgbmodel, X_test, num = 20, fig_size = (40, 20))
    # FILL ZEROS FOR PLOTTING
    input_ds = input_ds.fillna(value=0)
    f, ax = plt.subplots(1)
    f.set_figheight(5)
    f.set_figwidth(15)
    input_ds.loc['Sep-2020':'Oct-2020']['value'].plot(ax=ax, style=['-'])
    forecast.plot(ax=ax, style=['-'])
    ax.set_xbound(lower='2020-09', upper='2020-12')
    plot = plt.suptitle(filename, y=1.01)
    plot = plt.title('November Forecasted')
    plt.savefig(plots_dir+namerun+'_{}.png'.format(os.path.splitext(filename)[0]))
    predictions[filename] = list(forecast)
    results_df = pd.concat([results_df, forecast.rename({'additive':os.path.splitext(filename)[0]}, axis=1).T])
# Out:
# [I 2021-11-23 12:48:30,414] A new study created in memory with name: no-name-f58919c8-d6a8-4802-a12a-813dce7b5911
# /Users/evgenygenov/miniforge3/envs/native/lib/python3.8/site-packages/lightgbm/engine.py:148: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/evgenygenov/miniforge3/envs/native/lib/python3.8/site-packages/lightgbm/basic.py:1702: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004538 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3324
# [LightGBM] [Info] Number of data points in the train set: 92323, number of used features: 21
# [LightGBM] [Warning] Find whitespaces in feature_names, replace with underlines
# [LightGBM] [Info] Start training from score 5.387234
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's l1: 0.753595
# Training until validation scores don't improve for 50 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's l1: 0.706321
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's l1: 0.66251
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's l1: 0.622227
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's l1: 0.58393
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's l1: 0.549142
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's l1: 0.518924
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's l1: 0.487871
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0's l1: 0.461395
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's l1: 0.437809
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid_0's l1: 0.412325
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid_0's l1: 0.38952
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid_0's l1: 0.367785
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid_0's l1: 0.349916
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid_0's l1: 0.332364
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid_0's l1: 0.31569
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid_0's l1: 0.300895
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid_0's l1: 0.286386
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid_0's l1: 0.272918
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's l1: 0.260553
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid_0's l1: 0.248601
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid_0's l1: 0.237938
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid_0's l1: 0.228564
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid_0's l1: 0.220572
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid_0's l1: 0.213476
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid_0's l1: 0.206913
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid_0's l1: 0.201315
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid_0's l1: 0.196614
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid_0's l1: 0.191263
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid_0's l1: 0.186001
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid_0's l1: 0.181266
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid_0's l1: 0.177228
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid_0's l1: 0.174406
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid_0's l1: 0.171411
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid_0's l1: 0.168406
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid_0's l1: 0.166234
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [37]	valid_0's l1: 0.164344
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [38]	valid_0's l1: 0.16177
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	valid_0's l1: 0.15959
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's l1: 0.158024
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [41]	valid_0's l1: 0.155983
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [42]	valid_0's l1: 0.154128
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [43]	valid_0's l1: 0.152411
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [44]	valid_0's l1: 0.150947
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [45]	valid_0's l1: 0.149681
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [46]	valid_0's l1: 0.14925
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [47]	valid_0's l1: 0.148223
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [48]	valid_0's l1: 0.147326
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [49]	valid_0's l1: 0.146686
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	valid_0's l1: 0.145887
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [51]	valid_0's l1: 0.145039
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [52]	valid_0's l1: 0.143936
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [53]	valid_0's l1: 0.143507
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [54]	valid_0's l1: 0.142627
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [55]	valid_0's l1: 0.142279
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [56]	valid_0's l1: 0.141715
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [57]	valid_0's l1: 0.141492
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [58]	valid_0's l1: 0.141325
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [59]	valid_0's l1: 0.140657
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [60]	valid_0's l1: 0.140117
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [61]	valid_0's l1: 0.139513
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [62]	valid_0's l1: 0.139188
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [63]	valid_0's l1: 0.13874
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [64]	valid_0's l1: 0.138388
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [65]	valid_0's l1: 0.138003
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [66]	valid_0's l1: 0.137529
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [67]	valid_0's l1: 0.137321
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [68]	valid_0's l1: 0.137014
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [69]	valid_0's l1: 0.136633
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [70]	valid_0's l1: 0.136545
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [71]	valid_0's l1: 0.136539
# /Users/evgenygenov/miniforge3/envs/native/lib/python3.8/site-packages/lightgbm/basic.py:1433: UserWarning: Overriding the parameters from Reference Dataset.
#   _log_warning('Overriding the parameters from Reference Dataset.')
# /Users/evgenygenov/miniforge3/envs/native/lib/python3.8/site-packages/lightgbm/basic.py:1245: UserWarning: categorical_column in param dict is overridden.
#   _log_warning('{} in param dict is overridden.'.format(cat_alias))
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [72]	valid_0's l1: 0.136402
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [73]	valid_0's l1: 0.136117
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [74]	valid_0's l1: 0.136047
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [75]	valid_0's l1: 0.136047
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [76]	valid_0's l1: 0.135975
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [77]	valid_0's l1: 0.135894
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [78]	valid_0's l1: 0.135792
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [79]	valid_0's l1: 0.135598
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [80]	valid_0's

# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [247]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [248]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [249]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [250]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [251]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [252]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [253]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [254]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [255]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [256]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [257]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [258]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [259]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [260]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [261]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [262]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [263]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [264]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [265]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [266]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [267]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [268]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [269]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [270]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [271]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [272]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [273]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [274]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [275]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [276]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [277]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [278]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [279]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [280]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [281]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [282]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [283]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [284]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [285]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [286]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [287]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [288]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [289]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [290]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [291]	valid_0's l1: 0.132203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [292]	valid_0's l1: 0.132203
# Early stopping, best iteration is:
# [242]	valid_0's l1: 0.132203
# Finished loading model, total used 242 iterations
# Finished loading model, total used 242 iterations
# Finished loading model, total used 242 iterations
# Finished loading model, total used 242 iterations
# /Users/evgenygenov/miniforge3/envs/native/lib/python3.8/site-packages/lightgbm/engine.py:148: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/evgenygenov/miniforge3/envs/native/lib/python3.8/site-packages/lightgbm/basic.py:1702: UserWarning: Using categorical_feature in Dataset.
#   _log_warning('Using categorical_feature in Dataset.')
# [W 2021-11-23 12:48:33,560] Trial 2 failed because of the following error: TypeError('Wrong type(str) or unknown name(working) in categorical_feature')
# Traceback (most recent call last):
#   File "/Users/evgenygenov/miniforge3/envs/native/lib/python3.8/site-packages/optuna/study/_optimize.py", line 213, in _run_trial
#     value_or_values = func(trial)
#   File "/var/folders/8b/4kssy4kj57jb6rv1pmm5w8h80000gn/T/ipykernel_20310/2990647920.py", line 38, in <lambda>
#     func = lambda trial: objective(trial, input_X, input_y)
#   File "/var/folders/8b/4kssy4kj57jb6rv1pmm5w8h80000gn/T/ipykernel_20310/2849670594.py", line 79, in objective
#     model= lgb.train(
#   File "/Users/evgenygenov/miniforge3/envs/native/lib/python3.8/site-packages/lightgbm/engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "/Users/evgenygenov/miniforge3/envs/native/lib/python3.8/site-packages/lightgbm/basic.py", line 2229, in __init__
#     train_set.construct()
#   File "/Users/evgenygenov/miniforge3/envs/native/lib/python3.8/site-packages/lightgbm/basic.py", line 1468, in construct
#     self._lazy_init(self.data, label=self.label,
#   File "/Users/evgenygenov/miniforge3/envs/native/lib/python3.8/site-packages/lightgbm/basic.py", line 1240, in _lazy_init
#     raise TypeError("Wrong type({}) or unknown name({}) in categorical_feature"
# TypeError: Wrong type(str) or unknown name(working) in categorical_feature
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/8b/4kssy4kj57jb6rv1pmm5w8h80000gn/T/ipykernel_20310/2990647920.py in <module>
#      39
#      40     # Start optimizing with 100 trials
# ---> 41     study.optimize(func, n_trials=200, callbacks=[callback])
#      42
#      43     correlated_features = set()
#
# ~/miniforge3/envs/native/lib/python3.8/site-packages/optuna/study/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     398             )
#     399
# --> 400         _optimize(
#     401             study=self,
#     402             func=func,
#
# ~/miniforge3/envs/native/lib/python3.8/site-packages/optuna/study/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64     try:
#      65         if n_jobs == 1:
# ---> 66             _optimize_sequential(
#      67                 study,
#      68                 func,
#
# ~/miniforge3/envs/native/lib/python3.8/site-packages/optuna/study/_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     161
#     162         try:
# --> 163             trial = _run_trial(study, func, catch)
#     164         except Exception:
#     165             raise
#
# ~/miniforge3/envs/native/lib/python3.8/site-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     262
#     263     if state == TrialState.FAIL and func_err is not None and not isinstance(func_err, catch):
# --> 264         raise func_err
#     265     return trial
#     266
#
# ~/miniforge3/envs/native/lib/python3.8/site-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     211
#     212     try:
# --> 213         value_or_values = func(trial)
#     214     except exceptions.TrialPruned as e:
#     215         # TODO(mamu): Handle multi-objective cases.
#
# /var/folders/8b/4kssy4kj57jb6rv1pmm5w8h80000gn/T/ipykernel_20310/2990647920.py in <lambda>(trial)
#      36
#      37     # Pass additional arguments inside another function
# ---> 38     func = lambda trial: objective(trial, input_X, input_y)
#      39
#      40     # Start optimizing with 100 trials
#
# /var/folders/8b/4kssy4kj57jb6rv1pmm5w8h80000gn/T/ipykernel_20310/2849670594.py in objective(trial, input_X, input_y)
#      77     ds_validate = lgb.Dataset(X_eval, y_eval, categorical_feature=['working', 'weekday'])
#      78
# ---> 79     model= lgb.train(
#      80         train_set = ds_train,
#      81         #eval_set=[ds_validate],
#
# ~/miniforge3/envs/native/lib/python3.8/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     226     # construct booster
#     227     try:
# --> 228         booster = Booster(params=params, train_set=train_set)
#     229         if is_valid_contain_train:
#     230             booster.set_train_data_name(train_data_name)
#
# ~/miniforge3/envs/native/lib/python3.8/site-packages/lightgbm/basic.py in __init__(self, params, train_set, model_file, model_str, silent)
#    2227                 )
#    2228             # construct booster object
# -> 2229             train_set.construct()
#    2230             # copy the parameters from train_set
#    2231             params.update(train_set.get_params())
#
# ~/miniforge3/envs/native/lib/python3.8/site-packages/lightgbm/basic.py in construct(self)
#    1466             else:
#    1467                 # create train
# -> 1468                 self._lazy_init(self.data, label=self.label,
#    1469                                 weight=self.weight, group=self.group,
#    1470                                 init_score=self.init_score, predictor=self._predictor,
#
# ~/miniforge3/envs/native/lib/python3.8/site-packages/lightgbm/basic.py in _lazy_init(self, data, label, reference, weight, group, init_score, predictor, silent, feature_name, categorical_feature, params)
#    1238                     categorical_indices.add(name)
#    1239                 else:
# -> 1240                     raise TypeError("Wrong type({}) or unknown name({}) in categorical_feature"
#    1241                                     .format(type(name).__name__, name))
#    1242             if categorical_indices:
#
# TypeError: Wrong type(str) or unknown name(working) in categorical_feature

# %%
results_df.index = [os.path.splitext(filename)[0] for filename in buildings]
results_df = results_df.drop(labels=['Building5', 'Building4', 'Building6'], axis=0)
results_df.to_csv('./results/buildings_18Oct_lgbprophet.csv', header=False)
results_df
# Out:
# datetime   2020-11-01 00:00:00  2020-11-01 00:15:00  2020-11-01 00:30:00  \
# Building3           315.655691           324.881092           322.366539
# Building1            11.895682             2.396122             5.220512
# Building0            30.966833            22.669915            19.294705
#
# datetime   2020-11-01 00:45:00  2020-11-01 01:00:00  2020-11-01 01:15:00  \
# Building3           322.366539           320.768855           342.119936
# Building1             8.151713            11.774134             2.643530
# Building0            19.294705            12.115353            12.115353
#
# datetime   2020-11-01 01:30:00  2020-11-01 01:45:00  2020-11-01 02:00:00  \
# Building3           329.578025           329.578025           329.272119
# Building1             5.609308             7.950862            11.928921
# Building0            10.983254            10.983254            10.983254
#
# datetime   2020-11-01 02:15:00  ...  2020-11-30 21:30:00  2020-11-30 21:45:00  \
# Building3           308.277886  ...           433.590154           430.015694
# Building1             2.877235  ...            12.633003            18.026924
# Building0            10.983254  ...            91.832905            91.832905
#
# datetime   2020-11-30 22:00:00  2020-11-30 22:15:00  2020-11-30 22:30:00  \
# Building3           443.861004           472.305907           475.629616
# Building1            20.278981             5.791676            10.824637
# Building0            91.832905            72.840621            73.538447
#
# datetime   2020-11-30 22:45:00  2020-11-30 23:00:00  2020-11-30 23:15:00  \
# Building3           467.272392           464.441449           486.503359
# Building1            18.293966            23.270332             7.478956
# Building0            73.538447            73.538447            69.115314
#
# datetime   2020-11-30 23:30:00  2020-11-30 23:45:00
# Building3           487.857830           482.277186
# Building1            12.257391            18.270219
# Building0            70.494753            70.494753
#
# [3 rows x 2880 columns]
